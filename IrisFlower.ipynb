# %% [markdown]
# # Iris Flower Classification
# <img width= 100 height= 120 src="C:\Users\Maanvi\OneDrive\Desktop\iris.png" />

# %%
#Import libraries
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris

# %% [markdown]
# ## Load Data

# %%
#Load data
iris = load_iris(as_frame = True)
iris.keys()
df = iris.frame
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
#target names
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
#Dataset Characteristics
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %% [markdown]
# ## Data Visualization

# %%
df['target_name'] = df['target'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  target  target_name
# 0                5.1               3.5  ...       0       setosa
# 1                4.9               3.0  ...       0       setosa
# 2                4.7               3.2  ...       0       setosa
# 3                4.6               3.1  ...       0       setosa
# 4                5.0               3.6  ...       0       setosa
#
# [5 rows x 6 columns]

# %%
sns.scatterplot(df, x="sepal length (cm)", y="sepal width (cm)", hue="target_name")
plt.show()

# %%
sns.scatterplot(df, x="petal length (cm)", y="petal width (cm)", hue="target_name")
plt.show()

# %% [markdown]
# ## Split the data

# %%
#Split the data
X = X = df[["sepal length (cm)", "sepal width (cm)", "petal length (cm)", "petal width (cm)"]]
y = df["target"]
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y[:4]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# Name: target, dtype: int64

# %% [markdown]
# ## Train a Logistic Regression Model

# %%
#Train a Logistic Regression Model
from sklearn.linear_model import LogisticRegression

# Split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=5)

# Train logistic regression model 
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %% [markdown]
# ## Model Evaluation : Accuracy

# %%
model.score(X_test, y_test)
# Out:
# 0.9777777777777777

# %% [markdown]
# ## Model Evaluation: Precision, Recall, F1-Score

# %%
y_pred = model.predict(X_test)
y_pred[:10]
# Out:
# array([1, 2, 2, 0, 2, 1, 0, 2, 0, 1])

# %%
y_test[:10].tolist()
# Out:
# [1, 2, 2, 0, 2, 1, 0, 1, 0, 1]

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      0.94      0.97        16
#            2       0.93      1.00      0.97        14
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ## Model Evaluation : Confusion Matrix

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, xticklabels=iris.target_names, yticklabels=iris.target_names)   
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Conclusion : 15 flower predicted as Setosa while in reality there was actually 15 Setosa flowers. Model wrongly predicted 1 error with nearly 98 percent accuracy score.
